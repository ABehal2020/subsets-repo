# %%
import numpy as np
import scipy.io
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
import matplotlib.pyplot as plt

# Load the MATLAB file
file_path = '../Data/02_SVM_Accuracy.mat'
mat = scipy.io.loadmat(file_path)

# Explore the data structure to understand how to extract the needed data
var = [v for v in list(mat.keys())[3:] if 'Sig' not in v]
#print(var)
v01 = mat.get('subsetStartFromStartSpa').flatten()
v02 = mat.get('notSubsetStartFromStartSpa').flatten()
v03 = mat.get('subsetGoalFromStartSpa').flatten()
v04 = mat.get('notSubsetGoalFromStartSpa').flatten()
v05 = mat.get('subsetStartFromGoalSpa').flatten()
v06 = mat.get('notSubsetStartFromGoalSpa').flatten()
v07 = mat.get('subsetGoalFromGoalSpa').flatten()
v08 = mat.get('notSubsetGoalFromGoalSpa').flatten()
v09 = mat.get('subsetStartFromStartCue').flatten()
v10 = mat.get('notSubsetStartFromStartCue').flatten()
v11 = mat.get('subsetGoalFromStartCue').flatten()
v12 = mat.get('notSubsetGoalFromStartCue').flatten()
v13 = mat.get('subsetStartFromGoalCue').flatten()
v14 = mat.get('notSubsetStartFromGoalCue').flatten()
v15 = mat.get('subsetGoalFromGoalCue').flatten()
v16 = mat.get('notSubsetGoalFromGoalCue').flatten()

data1 = pd.DataFrame({'vals':np.concatenate((v01,v02,v03,v04,v05,v06,v07,v08,v09,v10,v11,v12,v13,v14,v15,v16),axis=0),
                      'task_type':np.concatenate((14*['spa'],14*['spa'],14*['spa'],14*['spa'],
                                                  14*['spa'],14*['spa'],14*['spa'],14*['spa'],
                                                  14*['cue'],14*['cue'],14*['cue'],14*['cue'],
                                                  14*['cue'],14*['cue'],14*['cue'],14*['cue']),axis=0),
                      'ensemble_type':np.concatenate((14*['subs'],14*['nsub'],14*['subs'],14*['nsub'],
                                                      14*['subs'],14*['nsub'],14*['subs'],14*['nsub'],
                                                      14*['subs'],14*['nsub'],14*['subs'],14*['nsub'],
                                                      14*['subs'],14*['nsub'],14*['subs'],14*['nsub']),axis=0),
                      'predicted_locs':np.concatenate((14*['start'],14*['start'],14*['goal'],14*['goal'],
                                                       14*['start'],14*['start'],14*['goal'],14*['goal'],
                                                       14*['start'],14*['start'],14*['goal'],14*['goal'],
                                                       14*['start'],14*['start'],14*['goal'],14*['goal']),axis=0),
                      'actual_locs':np.concatenate((14*['start'],14*['start'],14*['start'],14*['start'],
                                                       14*['goal'],14*['goal'],14*['goal'],14*['goal'],
                                                       14*['start'],14*['start'],14*['start'],14*['start'],
                                                       14*['goal'],14*['goal'],14*['goal'],14*['goal']),axis=0)
                     })

data1.head()
# Out:
#        vals task_type ensemble_type predicted_locs actual_locs
# 0  0.855094       spa          subs          start       start
# 1  0.880678       spa          subs          start       start
# 2  0.871373       spa          subs          start       start
# 3  0.863729       spa          subs          start       start
# 4  0.930566       spa          subs          start       start

# %%
model1 = ols('vals ~ C(task_type) + C(ensemble_type) + C(actual_locs) + C(predicted_locs) \
             + C(task_type):C(ensemble_type) + C(task_type):C(actual_locs) + C(task_type):C(predicted_locs) \
             + C(ensemble_type):C(actual_locs) + C(ensemble_type):C(predicted_locs) \
             + C(actual_locs):C(predicted_locs) \
             + C(task_type):C(ensemble_type):C(actual_locs) + C(task_type):C(ensemble_type):C(predicted_locs) \
             + C(task_type):C(actual_locs):C(predicted_locs) \
             + C(ensemble_type):C(actual_locs):C(predicted_locs) \
             + C(task_type):C(ensemble_type):C(actual_locs):C(predicted_locs)', data=data1).fit()
print(model1.summary())

# for an explanation on type 1 vs 2 vs 3: 
# https://mcfromnz.wordpress.com/2011/03/02/anova-type-iiiiii-ss-explained/
res1 = anova_lm(model1,typ=3)

print(res1)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   vals   R-squared:                       0.427
# Model:                            OLS   Adj. R-squared:                  0.385
# Method:                 Least Squares   F-statistic:                     10.33
# Date:                Fri, 23 Feb 2024   Prob (F-statistic):           2.72e-18
# Time:                        19:05:01   Log-Likelihood:                 221.68
# No. Observations:                 224   AIC:                            -411.4
# Df Residuals:                     208   BIC:                            -356.8
# Df Model:                          15
# Covariance Type:            nonrobust
# ===================================================================================================================================================================
#                                                                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                           0.8888      0.025     35.629      0.000       0.840       0.938
# C(task_type)[T.spa]                                                                                -0.0291      0.035     -0.825      0.410      -0.099       0.040
# C(ensemble_type)[T.subs]                                                                           -0.0026      0.035     -0.074      0.941      -0.072       0.067
# C(actual_locs)[T.start]                                                                            -0.1493      0.035     -4.231      0.000      -0.219      -0.080
# C(predicted_locs)[T.start]                                                                         -0.2331      0.035     -6.607      0.000      -0.303      -0.164
# C(task_type)[T.spa]:C(ensemble_type)[T.subs]                                                        0.0087      0.050      0.175      0.861      -0.090       0.107
# C(task_type)[T.spa]:C(actual_locs)[T.start]                                                         0.0031      0.050      0.062      0.950      -0.095       0.101
# C(task_type)[T.spa]:C(predicted_locs)[T.start]                                                      0.0546      0.050      1.095      0.275      -0.044       0.153
# C(ensemble_type)[T.subs]:C(actual_locs)[T.start]                                                    0.0555      0.050      1.113      0.267      -0.043       0.154
# C(ensemble_type)[T.subs]:C(predicted_locs)[T.start]                                                 0.0884      0.050      1.772      0.078      -0.010       0.187
# C(actual_locs)[T.start]:C(predicted_locs)[T.start]                                                  0.3722      0.050      7.461      0.000       0.274       0.471
# C(task_type)[T.spa]:C(ensemble_type)[T.subs]:C(actual_locs)[T.start]                                0.0225      0.071      0.319      0.750      -0.117       0.162
# C(task_type)[T.spa]:C(ensemble_type)[T.subs]:C(predicted_locs)[T.start]                            -0.0316      0.071     -0.447      0.655      -0.171       0.108
# C(task_type)[T.spa]:C(actual_locs)[T.start]:C(predicted_locs)[T.start]                             -0.0497      0.071     -0.704      0.482      -0.189       0.089
# C(ensemble_type)[T.subs]:C(actual_locs)[T.start]:C(predicted_locs)[T.start]                        -0.1494      0.071     -2.118      0.035      -0.289      -0.010
# C(task_type)[T.spa]:C(ensemble_type)[T.subs]:C(actual_locs)[T.start]:C(predicted_locs)[T.start]     0.0296      0.100      0.297      0.767      -0.167       0.226
# ==============================================================================
# Omnibus:                       13.017   Durbin-Watson:                   2.048
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.059
# Skew:                          -0.613   Prob(JB):                     0.000885
# Kurtosis:                       3.029   Cond. No.                         47.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                                        sum_sq     df  \
# Intercept                                           11.058986    1.0
# C(task_type)                                         0.005928    1.0
# C(ensemble_type)                                     0.000047    1.0
# C(actual_locs)                                       0.155947    1.0
# C(predicted_locs)                                    0.380318    1.0
# C(task_type):C(ensemble_type)                        0.000266    1.0
# C(task_type):C(actual_locs)                          0.000034    1.0
# C(task_type):C(predicted_locs)                       0.010448    1.0
# C(ensemble_type):C(actual_locs)                      0.010786    1.0
# C(ensemble_type):C(predicted_locs)                   0.027348    1.0
# C(actual_locs):C(predicted_locs)                     0.484899    1.0
# C(task_type):C(ensemble_type):C(actual_locs)         0.000885    1.0
# C(task_type):C(ensemble_type):C(predicted_locs)      0.001743    1.0
# C(task_type):C(actual_locs):C(predicted_locs)        0.004320    1.0
# C(ensemble_type):C(actual_locs):C(predicted_locs)    0.039086    1.0
# C(task_type):C(ensemble_type):C(actual_locs):C(...   0.000768    1.0
# Residual                                             1.812018  208.0
#
#                                                               F        PR(>F)
# Intercept                                           1269.451236  1.675774e-90
# C(task_type)                                           0.680449  4.103773e-01
# C(ensemble_type)                                       0.005408  9.414478e-01
# C(actual_locs)                                        17.901048  3.488226e-05
# C(predicted_locs)                                     43.656322  3.220953e-10
# C(task_type):C(ensemble_type)                          0.030578  8.613546e-01
# C(task_type):C(actual_locs)                            0.003897  9.502805e-01
# C(task_type):C(predicted_locs)                         1.199290  2.747301e-01
# C(ensemble_type):C(actual_locs)                        1.238123  2.671175e-01
# C(ensemble_type):C(predicted_locs)                     3.139271  7.789207e-02
# C(actual_locs):C(predicted_locs)                      55.661111  2.304167e-12
# C(task_type):C(ensemble_type):C(actual_locs)           0.101631  7.502008e-01
# C(task_type):C(ensemble_type):C(predicted_locs)        0.200086  6.551167e-01
# C(task_type):C(actual_locs):C(predicted_locs)          0.495834  4.821240e-01
# C(ensemble_type):C(actual_locs):C(predicted_locs)      4.486688  3.534679e-02
# C(task_type):C(ensemble_type):C(actual_locs):C(...     0.088204  7.667698e-01
# Residual                                                    NaN           NaN

# %%
# Type 2 anova of cell above
model1_T2 = ols('vals ~ C(task_type) + C(ensemble_type) + C(actual_locs) + C(predicted_locs) \
             + C(task_type):C(ensemble_type) + C(task_type):C(actual_locs) + C(task_type):C(predicted_locs) \
             + C(ensemble_type):C(actual_locs) + C(ensemble_type):C(predicted_locs) \
             + C(actual_locs):C(predicted_locs) \
             + C(task_type):C(ensemble_type):C(actual_locs) + C(task_type):C(ensemble_type):C(predicted_locs) \
             + C(task_type):C(actual_locs):C(predicted_locs) \
             + C(ensemble_type):C(actual_locs):C(predicted_locs) \
             + C(task_type):C(ensemble_type):C(actual_locs):C(predicted_locs)', data=data1).fit()
print(model1_T2.summary())

# for an explanation on type 1 vs 2 vs 3: 
# https://mcfromnz.wordpress.com/2011/03/02/anova-type-iiiiii-ss-explained/
res1_T2 = anova_lm(model1_T2,typ=2)

print(res1_T2)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   vals   R-squared:                       0.427
# Model:                            OLS   Adj. R-squared:                  0.385
# Method:                 Least Squares   F-statistic:                     10.33
# Date:                Fri, 23 Feb 2024   Prob (F-statistic):           2.72e-18
# Time:                        19:05:10   Log-Likelihood:                 221.68
# No. Observations:                 224   AIC:                            -411.4
# Df Residuals:                     208   BIC:                            -356.8
# Df Model:                          15
# Covariance Type:            nonrobust
# ===================================================================================================================================================================
#                                                                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                           0.8888      0.025     35.629      0.000       0.840       0.938
# C(task_type)[T.spa]                                                                                -0.0291      0.035     -0.825      0.410      -0.099       0.040
# C(ensemble_type)[T.subs]                                                                           -0.0026      0.035     -0.074      0.941      -0.072       0.067
# C(actual_locs)[T.start]                                                                            -0.1493      0.035     -4.231      0.000      -0.219      -0.080
# C(predicted_locs)[T.start]                                                                         -0.2331      0.035     -6.607      0.000      -0.303      -0.164
# C(task_type)[T.spa]:C(ensemble_type)[T.subs]                                                        0.0087      0.050      0.175      0.861      -0.090       0.107
# C(task_type)[T.spa]:C(actual_locs)[T.start]                                                         0.0031      0.050      0.062      0.950      -0.095       0.101
# C(task_type)[T.spa]:C(predicted_locs)[T.start]                                                      0.0546      0.050      1.095      0.275      -0.044       0.153
# C(ensemble_type)[T.subs]:C(actual_locs)[T.start]                                                    0.0555      0.050      1.113      0.267      -0.043       0.154
# C(ensemble_type)[T.subs]:C(predicted_locs)[T.start]                                                 0.0884      0.050      1.772      0.078      -0.010       0.187
# C(actual_locs)[T.start]:C(predicted_locs)[T.start]                                                  0.3722      0.050      7.461      0.000       0.274       0.471
# C(task_type)[T.spa]:C(ensemble_type)[T.subs]:C(actual_locs)[T.start]                                0.0225      0.071      0.319      0.750      -0.117       0.162
# C(task_type)[T.spa]:C(ensemble_type)[T.subs]:C(predicted_locs)[T.start]                            -0.0316      0.071     -0.447      0.655      -0.171       0.108
# C(task_type)[T.spa]:C(actual_locs)[T.start]:C(predicted_locs)[T.start]                             -0.0497      0.071     -0.704      0.482      -0.189       0.089
# C(ensemble_type)[T.subs]:C(actual_locs)[T.start]:C(predicted_locs)[T.start]                        -0.1494      0.071     -2.118      0.035      -0.289      -0.010
# C(task_type)[T.spa]:C(ensemble_type)[T.subs]:C(actual_locs)[T.start]:C(predicted_locs)[T.start]     0.0296      0.100      0.297      0.767      -0.167       0.226
# ==============================================================================
# Omnibus:                       13.017   Durbin-Watson:                   2.048
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.059
# Skew:                          -0.613   Prob(JB):                     0.000885
# Kurtosis:                       3.029   Cond. No.                         47.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                                       sum_sq     df  \
# C(task_type)                                        0.002625    1.0
# C(ensemble_type)                                    0.080004    1.0
# C(actual_locs)                                      0.037006    1.0
# C(predicted_locs)                                   0.048525    1.0
# C(task_type):C(ensemble_type)                       0.001883    1.0
# C(task_type):C(actual_locs)                         0.000132    1.0
# C(task_type):C(predicted_locs)                      0.006425    1.0
# C(ensemble_type):C(actual_locs)                     0.000004    1.0
# C(ensemble_type):C(predicted_locs)                  0.000393    1.0
# C(actual_locs):C(predicted_locs)                    1.098038    1.0
# C(task_type):C(ensemble_type):C(actual_locs)        0.004872    1.0
# C(task_type):C(ensemble_type):C(predicted_locs)     0.000981    1.0
# C(task_type):C(actual_locs):C(predicted_locs)       0.004254    1.0
# C(ensemble_type):C(actual_locs):C(predicted_locs)   0.063440    1.0
# C(task_type):C(ensemble_type):C(actual_locs):C(...  0.000768    1.0
# Residual                                            1.812018  208.0
#
#                                                              F        PR(>F)
# C(task_type)                                          0.301286  5.836663e-01
# C(ensemble_type)                                      9.183542  2.751879e-03
# C(actual_locs)                                        4.247868  4.054348e-02
# C(predicted_locs)                                     5.570157  1.919447e-02
# C(task_type):C(ensemble_type)                         0.216205  6.424333e-01
# C(task_type):C(actual_locs)                           0.015161  9.021243e-01
# C(task_type):C(predicted_locs)                        0.737565  3.914307e-01
# C(ensemble_type):C(actual_locs)                       0.000497  9.822276e-01
# C(ensemble_type):C(predicted_locs)                    0.045130  8.319739e-01
# C(actual_locs):C(predicted_locs)                    126.042862  3.579628e-23
# C(task_type):C(ensemble_type):C(actual_locs)          0.559260  4.554030e-01
# C(task_type):C(ensemble_type):C(predicted_locs)       0.112628  7.375101e-01
# C(task_type):C(actual_locs):C(predicted_locs)         0.488369  4.854363e-01
# C(ensemble_type):C(actual_locs):C(predicted_locs)     7.282272  7.535980e-03
# C(task_type):C(ensemble_type):C(actual_locs):C(...    0.088204  7.667698e-01
# Residual                                                   NaN           NaN

# %%
# Load the MATLAB file
file_path = '../Data/03_Unit_Spatial_Information.mat'
mat = scipy.io.loadmat(file_path)

# Explore the data structure to understand how to extract the needed data
var = [v for v in list(mat.keys())[3:] if 'Sig' not in v]
print(var)

lens = [len(mat.get(v).flatten()) for v in var]
print(lens)
# Out:
# ['spaSubsetTotal', 'spaSubsetStart', 'spaSubsetGoal', 'spaNotSubsetTotal', 'spaNotSubsetStart', 'spaNotSubsetGoal', 'cueSubsetTotal', 'cueSubsetStart', 'cueSubsetGoal', 'cueNotSubsetTotal', 'cueNotSubsetStart', 'cueNotSubsetGoal']
# [108, 108, 108, 492, 492, 492, 90, 90, 90, 510, 510, 510]

# %%
# Load the MATLAB file
file_path = '../Data/03_Unit_Spatial_Information.mat'
mat = scipy.io.loadmat(file_path)

# Explore the data structure to understand how to extract the needed data
var = [v for v in list(mat.keys())[3:] if 'Sig' not in v]
#print(var)
v01 = mat.get('spaSubsetTotal').flatten()
v02 = mat.get('spaSubsetStart').flatten()
v03 = mat.get('spaSubsetGoal').flatten()
v04 = mat.get('spaNotSubsetTotal').flatten()
v05 = mat.get('spaNotSubsetStart').flatten()
v06 = mat.get('spaNotSubsetGoal').flatten()
v07 = mat.get('cueSubsetTotal').flatten()
v08 = mat.get('cueSubsetStart').flatten()
v09 = mat.get('cueSubsetGoal').flatten()
v10 = mat.get('cueNotSubsetTotal').flatten()
v11 = mat.get('cueNotSubsetStart').flatten()
v12 = mat.get('cueNotSubsetGoal').flatten()

data2 = pd.DataFrame({'vals':np.concatenate((v01,v02,v03,v04,v05,v06,v07,v08,v09,v10,v11,v12),axis=0),
                      'task_type':np.concatenate((108*['spa'],108*['spa'],108*['spa'],
                                                  492*['spa'],492*['spa'],492*['spa'],
                                                  90*['cue'],90*['cue'],90*['cue'],
                                                  510*['cue'],510*['cue'],510*['cue']),axis=0),
                      'ensemble_type':np.concatenate((108*['subs'],108*['subs'],108*['subs'],
                                                      492*['nsubs'],492*['nsubs'],492*['nsubs'],
                                                      90*['subs'],90*['subs'],90*['subs'],
                                                      510*['nsubs'],510*['nsubs'],510*['nsubs']),axis=0),
                      'information_type':np.concatenate((108*['total'],108*['start'],108*['goal'],
                                                         492*['total'],492*['start'],492*['goal'],
                                                         90*['total'],90*['start'],90*['goal'],
                                                         510*['total'],510*['start'],510*['goal']),axis=0)
                     })

data2.head()
# Out:
#         vals task_type ensemble_type information_type
# 0   7.169124       spa          subs            total
# 1   6.189314       spa          subs            total
# 2  16.637914       spa          subs            total
# 3   6.853969       spa          subs            total
# 4   3.356084       spa          subs            total

# %%
model2 = ols('vals ~ C(task_type) + C(ensemble_type) + C(information_type) + \
             C(task_type):C(ensemble_type) + C(task_type):C(information_type) + \
             C(ensemble_type):C(information_type) + \
             C(task_type):C(ensemble_type):C(information_type)', data=data2).fit()
print(model2.summary())
res2 = anova_lm(model2,typ=2)
print(res2)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   vals   R-squared:                       0.057
# Model:                            OLS   Adj. R-squared:                  0.055
# Method:                 Least Squares   F-statistic:                     19.89
# Date:                Wed, 27 Dec 2023   Prob (F-statistic):           1.75e-39
# Time:                        10:03:06   Log-Likelihood:                -8879.9
# No. Observations:                3600   AIC:                         1.778e+04
# Df Residuals:                    3588   BIC:                         1.786e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# =============================================================================================================================================
#                                                                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                     2.4272      0.126     19.193      0.000       2.179       2.675
# C(task_type)[T.spa]                                                           0.3551      0.180      1.968      0.049       0.001       0.709
# C(ensemble_type)[T.subs]                                                     -0.0806      0.327     -0.247      0.805      -0.721       0.560
# C(information_type)[T.start]                                                 -0.5918      0.179     -3.309      0.001      -0.942      -0.241
# C(information_type)[T.total]                                                  0.9896      0.179      5.533      0.000       0.639       1.340
# C(task_type)[T.spa]:C(ensemble_type)[T.subs]                                  0.2455      0.446      0.551      0.582      -0.629       1.119
# C(task_type)[T.spa]:C(information_type)[T.start]                             -0.2417      0.255     -0.947      0.344      -0.742       0.259
# C(task_type)[T.spa]:C(information_type)[T.total]                             -0.1486      0.255     -0.582      0.560      -0.649       0.352
# C(ensemble_type)[T.subs]:C(information_type)[T.start]                        -0.3259      0.462     -0.706      0.480      -1.231       0.579
# C(ensemble_type)[T.subs]:C(information_type)[T.total]                        -0.2529      0.462     -0.548      0.584      -1.158       0.652
# C(task_type)[T.spa]:C(ensemble_type)[T.subs]:C(information_type)[T.start]    -0.2880      0.630     -0.457      0.648      -1.524       0.948
# C(task_type)[T.spa]:C(ensemble_type)[T.subs]:C(information_type)[T.total]     0.0422      0.630      0.067      0.947      -1.194       1.278
# ==============================================================================
# Omnibus:                     4074.485   Durbin-Watson:                   1.754
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           864905.834
# Skew:                           5.476   Prob(JB):                         0.00
# Kurtosis:                      78.140   Cond. No.                         27.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                                          sum_sq      df  \
# C(task_type)                                          56.958127     1.0
# C(ensemble_type)                                      17.090890     1.0
# C(information_type)                                 1674.112258     2.0
# C(task_type):C(ensemble_type)                          3.292754     1.0
# C(task_type):C(information_type)                      12.505011     2.0
# C(ensemble_type):C(information_type)                  19.057761     2.0
# C(task_type):C(ensemble_type):C(information_type)      2.650648     2.0
# Residual                                           29263.934226  3588.0
#
#                                                             F        PR(>F)
# C(task_type)                                         6.983537  8.262033e-03
# C(ensemble_type)                                     2.095484  1.478223e-01
# C(information_type)                                102.629994  4.535706e-44
# C(task_type):C(ensemble_type)                        0.403719  5.252154e-01
# C(task_type):C(information_type)                     0.766609  4.646620e-01
# C(ensemble_type):C(information_type)                 1.168319  3.110072e-01
# C(task_type):C(ensemble_type):C(information_type)    0.162496  8.500260e-01
# Residual                                                  NaN           NaN

# %%
# Load the MATLAB file
file_path = '../Data/04_Normed_PV_Information.mat'
mat = scipy.io.loadmat(file_path)

v01 = mat.get('spaSubsetStartDecStart').flatten()
v02 = mat.get('spaNotSubsetStartDecStart').flatten()
v03 = mat.get('spaSubsetStartDecGoal').flatten()
v04 = mat.get('spaNotSubsetStartDecGoal').flatten()
v05 = mat.get('spaSubsetGoalDecStart').flatten()
v06 = mat.get('spaNotSubsetGoalDecStart').flatten()
v07 = mat.get('spaSubsetGoalDecGoal').flatten()
v08 = mat.get('spaNotSubsetGoalDecGoal').flatten()
v09 = mat.get('cueSubsetStartDecStart').flatten()
v10 = mat.get('cueNotSubsetStartDecStart').flatten()
v11 = mat.get('cueSubsetStartDecGoal').flatten()
v12 = mat.get('cueNotSubsetStartDecGoal').flatten()
v13 = mat.get('cueSubsetGoalDecStart').flatten()
v14 = mat.get('cueNotSubsetGoalDecStart').flatten()
v15 = mat.get('cueSubsetGoalDecGoal').flatten()
v16 = mat.get('cueNotSubsetGoalDecGoal').flatten()

data3 = pd.DataFrame({'vals':np.concatenate((v01,v02,v03,v04,v05,v06,v07,v08,v09,v10,v11,v12,v13,v14,v15,v16),axis=0),
                      'task_type':np.concatenate((758*['spa'],758*['spa'],758*['spa'],758*['spa'],
                                                  758*['spa'],758*['spa'],758*['spa'],758*['spa'],
                                                  827*['cue'],827*['cue'],827*['cue'],827*['cue'],
                                                  827*['cue'],827*['cue'],827*['cue'],827*['cue']),axis=0),
                      'ensemble_type':np.concatenate((758*['subs'],758*['nsub'],758*['subs'],758*['nsub'],
                                                      758*['subs'],758*['nsub'],758*['subs'],758*['nsub'],
                                                      827*['subs'],827*['nsub'],827*['subs'],827*['nsub'],
                                                      827*['subs'],827*['nsub'],827*['subs'],827*['nsub']),axis=0),
                      'actual_locs':np.concatenate((758*['start'],758*['start'],758*['start'],758*['start'],
                                                    758*['goal'],758*['goal'],758*['goal'],758*['goal'],
                                                    827*['start'],827*['start'],827*['start'],827*['start'],
                                                    827*['goal'],827*['goal'],827*['goal'],827*['goal']),axis=0),
                      'predicted_locs':np.concatenate((758*['start'],758*['start'],758*['goal'],758*['goal'],
                                                       758*['start'],758*['start'],758*['goal'],758*['goal'],
                                                       827*['start'],827*['start'],827*['goal'],827*['goal'],
                                                       827*['start'],827*['start'],827*['goal'],827*['goal']),axis=0)
                     })

data3.head()
# Out:
#        vals task_type ensemble_type actual_locs predicted_locs
# 0  0.662857       spa          subs       start          start
# 1  0.976455       spa          subs       start          start
# 2  1.095636       spa          subs       start          start
# 3  1.133634       spa          subs       start          start
# 4  0.800119       spa          subs       start          start

# %%
model3 = ols('vals ~ C(task_type) + C(ensemble_type) + C(actual_locs) + C(predicted_locs) \
             + C(task_type):C(ensemble_type) + C(task_type):C(actual_locs) + C(task_type):C(predicted_locs) \
             + C(ensemble_type):C(actual_locs) + C(ensemble_type):C(predicted_locs) \
             + C(actual_locs):C(predicted_locs) \
             + C(task_type):C(ensemble_type):C(actual_locs) + C(task_type):C(ensemble_type):C(predicted_locs) \
             + C(task_type):C(actual_locs):C(predicted_locs) \
             + C(ensemble_type):C(actual_locs):C(predicted_locs) \
             + C(task_type):C(ensemble_type):C(actual_locs):C(predicted_locs)', data=data3).fit()
print(model3.summary())
res3 = anova_lm(model3,typ=2)
print(res3)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   vals   R-squared:                       0.051
# Model:                            OLS   Adj. R-squared:                  0.050
# Method:                 Least Squares   F-statistic:                     45.62
# Date:                Wed, 27 Dec 2023   Prob (F-statistic):          2.13e-132
# Time:                        10:03:07   Log-Likelihood:                -16264.
# No. Observations:               12680   AIC:                         3.256e+04
# Df Residuals:                   12664   BIC:                         3.268e+04
# Df Model:                          15
# Covariance Type:            nonrobust
# ===================================================================================================================================================================
#                                                                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                           1.1279      0.030     37.147      0.000       1.068       1.187
# C(task_type)[T.spa]                                                                                -0.0013      0.044     -0.029      0.976      -0.087       0.085
# C(ensemble_type)[T.subs]                                                                            0.0616      0.043      1.436      0.151      -0.023       0.146
# C(actual_locs)[T.start]                                                                            -0.0304      0.043     -0.708      0.479      -0.115       0.054
# C(predicted_locs)[T.start]                                                                         -0.2950      0.043     -6.871      0.000      -0.379      -0.211
# C(task_type)[T.spa]:C(ensemble_type)[T.subs]                                                       -0.0110      0.062     -0.177      0.860      -0.133       0.111
# C(task_type)[T.spa]:C(actual_locs)[T.start]                                                         0.4796      0.062      7.725      0.000       0.358       0.601
# C(task_type)[T.spa]:C(predicted_locs)[T.start]                                                      0.2090      0.062      3.367      0.001       0.087       0.331
# C(ensemble_type)[T.subs]:C(actual_locs)[T.start]                                                    0.0135      0.061      0.223      0.823      -0.105       0.133
# C(ensemble_type)[T.subs]:C(predicted_locs)[T.start]                                                -0.0121      0.061     -0.199      0.842      -0.131       0.107
# C(actual_locs)[T.start]:C(predicted_locs)[T.start]                                                  0.2309      0.061      3.803      0.000       0.112       0.350
# C(task_type)[T.spa]:C(ensemble_type)[T.subs]:C(actual_locs)[T.start]                                0.0173      0.088      0.197      0.843      -0.155       0.189
# C(task_type)[T.spa]:C(ensemble_type)[T.subs]:C(predicted_locs)[T.start]                             0.0200      0.088      0.228      0.820      -0.152       0.192
# C(task_type)[T.spa]:C(actual_locs)[T.start]:C(predicted_locs)[T.start]                             -0.6415      0.088     -7.305      0.000      -0.814      -0.469
# C(ensemble_type)[T.subs]:C(actual_locs)[T.start]:C(predicted_locs)[T.start]                        -0.0897      0.086     -1.045      0.296      -0.258       0.079
# C(task_type)[T.spa]:C(ensemble_type)[T.subs]:C(actual_locs)[T.start]:C(predicted_locs)[T.start]     0.0208      0.124      0.168      0.867      -0.223       0.264
# ==============================================================================
# Omnibus:                     8385.279   Durbin-Watson:                   1.887
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            95212.856
# Skew:                           3.132   Prob(JB):                         0.00
# Kurtosis:                      14.873   Cond. No.                         46.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                                          sum_sq       df  \
# C(task_type)                                         113.183260      1.0
# C(ensemble_type)                                       6.738717      1.0
# C(actual_locs)                                        73.279900      1.0
# C(predicted_locs)                                    204.806057      1.0
# C(task_type):C(ensemble_type)                          0.131881      1.0
# C(task_type):C(actual_locs)                           23.612552      1.0
# C(task_type):C(predicted_locs)                         7.361986      1.0
# C(ensemble_type):C(actual_locs)                        0.257901      1.0
# C(ensemble_type):C(predicted_locs)                     1.425301      1.0
# C(actual_locs):C(predicted_locs)                      10.613662      1.0
# C(task_type):C(ensemble_type):C(actual_locs)           0.152350      1.0
# C(task_type):C(ensemble_type):C(predicted_locs)        0.183393      1.0
# C(task_type):C(actual_locs):C(predicted_locs)         78.756615      1.0
# C(ensemble_type):C(actual_locs):C(predicted_locs)      1.260219      1.0
# C(task_type):C(ensemble_type):C(actual_locs):C(...     0.021463      1.0
# Residual                                            9655.389704  12664.0
#
#                                                              F        PR(>F)
# C(task_type)                                        148.451057  5.855045e-34
# C(ensemble_type)                                      8.838495  2.954973e-03
# C(actual_locs)                                       96.113848  1.305326e-22
# C(predicted_locs)                                   268.623430  9.322066e-60
# C(task_type):C(ensemble_type)                         0.172975  6.774880e-01
# C(task_type):C(actual_locs)                          30.970201  2.673431e-08
# C(task_type):C(predicted_locs)                        9.655973  1.891545e-03
# C(ensemble_type):C(actual_locs)                       0.338262  5.608443e-01
# C(ensemble_type):C(predicted_locs)                    1.869423  1.715654e-01
# C(actual_locs):C(predicted_locs)                     13.920869  1.915027e-04
# C(task_type):C(ensemble_type):C(actual_locs)          0.199823  6.548718e-01
# C(task_type):C(ensemble_type):C(predicted_locs)       0.240537  6.238267e-01
# C(task_type):C(actual_locs):C(predicted_locs)       103.297101  3.571501e-24
# C(ensemble_type):C(actual_locs):C(predicted_locs)     1.652902  1.985879e-01
# C(task_type):C(ensemble_type):C(actual_locs):C(...    0.028151  8.667568e-01
# Residual                                                   NaN           NaN
